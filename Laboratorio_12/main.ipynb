# %% [markdown]
# ### IMPORTAR LIBRERIAS

# %%
import random
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# ### 1. Creen un arreglo de 5x5 donde los números sean aleatorios del 1 al 10.

# %%
matrix = []
for i in range(5):
  matrix.append([])
  for j in range(5):
    matrix[i].append(random.randint(0,10))

for i in range(5):
        for j in range(5):
            print(matrix[i][j], end=" ")
        print()
# Out:
# 9 3 1 2 8
# 1 0 10 10 10
# 7 7 7 2 4
# 4 10 3 2 4
# 1 1 4 3 2

# %% [markdown]
# ### 2. Muestren solo el canal azul de la figura

# %%
img = cv2.imread('test.jpg')
img_blue = img[:,:,0]

cv2.imwrite('test_blue.jpg', img_blue)
img_blue = mpimg.imread('test_blue.jpg')

plt.imshow(img_blue)
plt.show()

# %% [markdown]
# ### 3.Cambien la imagen a escala de grises.

# %%
img = cv2.imread('test.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_blue, cmap='gray')

# %% [markdown]
# ### 4.Guarden una nueva imagen que contenga solo los canales rojo y verde

# %%
image = cv2.imread('test.jpg')

red_green = image.copy()
red_green[:, :,0] = 0

cv2.imwrite('test_red_green.jpg', red_green)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ### 5.Guarden una nueva imagen que muestre la imagen en escala de grises

# %%
image = cv2.imread('test.jpg')

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

cv2.imwrite('test_gray_scale.jpg', gray)
cv2.waitKey(0)
# Out:
# -1
